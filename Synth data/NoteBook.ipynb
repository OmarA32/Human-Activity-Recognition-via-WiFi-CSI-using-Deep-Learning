# %%
# !pip install gdown

# %%
import zipfile
import os
import gdown
# Download the file using gdown
file_id = "1fEiI3nAoOsddR5qcJQXqz4ocM3aMAcwz"
output_name = "UT_HAR.zip"
# !gdown --id $file_id -O "/content/$output_name"

zip_path = "/content/UT_HAR.zip"
extract_to = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Unzipped UT_HAR.zip into:", extract_to)
print("Contents:", os.listdir(extract_to))
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1fEiI3nAoOsddR5qcJQXqz4ocM3aMAcwz
# From (redirected): https://drive.google.com/uc?id=1fEiI3nAoOsddR5qcJQXqz4ocM3aMAcwz&confirm=t&uuid=0fbb19f1-9fcd-4d09-a8b3-8f5de373693e
# To: /content/UT_HAR.zip
# 100% 383M/383M [00:06<00:00, 60.3MB/s]
# Unzipped UT_HAR.zip into: /content/
# Contents: ['.config', 'autoencoder_full.py', 'UT_HAR.zip', 'generate_synthetic_ut_har_colab.py', 'UT_HAR', 'sample_data']

# %%
# !pip install torch torchvision
# !pip install lpips
# !pip install numpy
# !pip install scipy
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# %run autoencoder_full.py -class 0

# %%
# %run autoencoder_full.py -class 1

# %%
# %run autoencoder_full.py -class 2

# %%
# %run autoencoder_full.py -class 3

# %%
# %run autoencoder_full.py -class 4

# %%
# %run autoencoder_full.py -class 5

# %%
# %run autoencoder_full.py -class 6

# %%
# %run generate_synthetic_ut_har_colab.py -class 0

# %%
# %run pca_full.py --class 0

# %%
# %run generate_synthetic_ut_har_colab_pca.py --class 0
